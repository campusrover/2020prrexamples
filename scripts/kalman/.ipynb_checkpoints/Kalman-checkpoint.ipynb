# %%
import csv
import numpy as np
import pandas as pd
import math as m

# %%
def kalman_update(index, elapsed, m_dist, e_dist):
    e_dist = e_dist+(0.5)*(m_dist-e_dist)
    return (e_dist)

# %%
def kalman_control(elapsed, e_forw, e_dist, e_bear):
    e_bear = m.radians(e_bear)
    print(e_dist, e_bear, e_forw)
    e_bear = m.atan((e_dist*m.sin(e_bear))/(e_forw-e_dist*m.cos(e_bear)))
    print(e_bear)
    return m.degrees(e_bear)

# %%
kalman_control(1, 0, 0.67, 258)
# Out:
# 0.67 4.50294947014537 0
# -1.3613568165555765
# 258.0

# %%
df=pd.read_csv('kalman_test_data.csv', sep=',')
# elapsed,g_forward_cmd,g_turn_cmd,g_shortest_bearing,g_shortest
df.insert(5, 'new_dist', 0)
df.insert(6, 'new_bear', 0)

# %%
est_dist = 1.5
est_bear = 0
for index, row in df.iterrows():
    elapsed = row['elapsed']
    meas_dist = row['g_shortest']
    meas_bear = row['g_shortest_bearing']
    fwd_cmd = row['g_forward_cmd']
    turn_cmd = row['g_turn_cmd']
    est_dist = kalman_update(index+1, elapsed, meas_dist, est_dist)
    est_bear = kalman_control(elapsed, fwd_cmd, est_dist, meas_bear)
    df.loc[df.index[index], 'new_dist'] = est_dist
    df.loc[df.index[index], 'new_bear'] = est_bear
# Out:
# 1.516 5.707226654021458 0.0
# 0.5759586531581287
# 1.5295 5.707226654021458 0.0
# 0.5759586531581287
# 1.5362500000000001 5.707226654021458 0.0
# 0.5759586531581287
# 1.5376250000000002 5.724679946541401 0.0
# 0.5585053606381856
# 1.5383125000000002 5.724679946541401 0.0
# 0.5585053606381856
# 1.54065625 5.724679946541401 0.0
# 0.5585053606381856
# 1.5373281250000002 5.707226654021458 0.0
# 0.5759586531581287
# 1.5356640625 5.707226654021458 0.0
# 0.5759586531581287
# 1.53833203125 5.724679946541401 0.0
# 0.5585053606381856
# 1.539666015625 5.724679946541401 0.0
# 0.5585053606381856
# 1.5433330078125 5.724679946541401 0.0
# 0.5585053606381856
# 1.54216650390625 5.724679946541401 0.0
# 0.5585053606381856
# 1.546583251953125 5.707226654021458 0.0
# 0.5759586531581287
# 1.5437916259765625 5.707226654021458 0.0
# 0.5759586531581287
# 1.5398958129882812 5.724679946541401 0.0
# 0.5585053606381856
# 1.5379479064941406 5.724679946541401 0.0
# 0.5585053606381856
# ...

# %%
df
# Out:
#     elapsed  g_forward_cmd  g_turn_cmd  g_shortest_bearing  g_shortest  \
# 0     0.198            0.0         0.0               327.0       1.532
# 1     0.202            0.0         0.0               327.0       1.543
# 2     0.197            0.0         0.0               327.0       1.543
# 3     0.202            0.0         0.0               328.0       1.539
# 4     0.200            0.0         0.0               328.0       1.539
# 5     0.198            0.0         0.0               328.0       1.543
# 6     0.200            0.0         0.0               327.0       1.534
# 7     0.200            0.0         0.0               327.0       1.534
# 8     0.208            0.0         0.0               328.0       1.541
# 9     0.191            0.0         0.0               328.0       1.541
# 10    0.203            0.0         0.0               328.0       1.547
# 11    0.197            0.0         0.0               328.0       1.541
# ...

# %%
def test1(val1, val2):
    return (val1+100, val2+100)

# %%
foo = 12
bar = -20

for i in range(1,100):
    (x,y) = test1(foo, bar)
    foo = x
    bar = y
    print(foo,bar)
# Out:
# 112 80
# 212 180
# 312 280
# 412 380
# 512 480
# 612 580
# 712 680
# 812 780
# 912 880
# 1012 980
# 1112 1080
# 1212 1180
# 1312 1280
# 1412 1380
# 1512 1480
# 1612 1580
# 1712 1680
# 1812 1780
# 1912 1880
# 2012 1980
# 2112 2080
# 2212 2180
# 2312 2280
# 2412 2380
# 2512 2480
# 2612 2580
# 2712 2680
# 2812 2780
# 2912 2880
# 3012 2980
# 3112 3080
# 3212 3180
# 3312 3280
# 3412 3380
# 3512 3480
# 3612 3580
# 3712 3680
# 3812 3780
# 3912 3880
# 4012 3980
# 4112 4080
# 4212 4180
# 4312 4280
# 4412 4380
# 4512 4480
# 4612 4580
# 4712 4680
# 4812 4780
# 4912 4880
# 5012 4980
# 5112 5080
# 5212 5180
# 5312 5280
# 5412 5380
# 5512 5480
# 5612 5580
# 5712 5680
# 5812 5780
# 5912 5880
# 6012 5980
# 6112 6080
# 6212 6180
# 6312 6280
# 6412 6380
# 6512 6480
# 6612 6580
# 6712 6680
# 6812 6780
# 6912 6880
# 7012 6980
# 7112 7080
# 7212 7180
# 7312 7280
# 7412 7380
# 7512 7480
# 7612 7580
# 7712 7680
# 7812 7780
# 7912 7880
# 8012 7980
# 8112 8080
# 8212 8180
# 8312 8280
# 8412 8380
# 8512 8480
# ...
